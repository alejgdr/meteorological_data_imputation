# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import timedelta
from pandas.plotting import register_matplotlib_converters
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from time import time
from dateutil.parser import parse
import impute as imp
import calplot

# %% [markdown]
# # Importo datos de anio incompleto

# %%
path_archivo='../../01_weather_data/03_imputing_process/01_test_data/'#camino para llegar a archivo a importar
nombre_archivo='Temixco_2018_incomplete_maxmin_mae_solar_angles.csv'# archivo a importar
tmx_inc=pd.read_csv(path_archivo+nombre_archivo,parse_dates=True)
tmx_inc
# Out:
#                       time   Ib   Ig     to     RH         P     WS     WD  \
# 0      2018-01-01 00:00:00  0.0  0.0  18.70  36.34  87864.11  1.422  316.0
# 1      2018-01-01 00:10:00  0.0  0.0  18.95  35.29  87876.37  1.008  283.7
# 2      2018-01-01 00:20:00  0.0  0.0  18.94  35.43  87888.64  1.565  326.0
# 3      2018-01-01 00:30:00  0.0  0.0  18.77  35.89  87887.21  2.175  354.5
# 4      2018-01-01 00:40:00  0.0  0.0  18.81  36.34  87886.91  1.902  348.0
# ...                    ...  ...  ...    ...    ...       ...    ...    ...
# 52555  2018-12-31 23:10:00  0.0  0.0  18.51  47.29  87484.32  1.715  332.2
# 52556  2018-12-31 23:20:00  0.0  0.0  18.26  48.02  87470.70  1.703  320.5
# 52557  2018-12-31 23:30:00  0.0  0.0  18.39  46.84  87455.03  2.887  335.7
# 52558  2018-12-31 23:40:00  0.0  0.0  17.99  47.85  87470.02  1.528  358.8
# 52559  2018-12-31 23:50:00  0.0  0.0  17.75  49.65  87467.29  0.598  322.3
#
#        alturasolar     azimuth
# 0       -79.806160  166.773196
# 1       -81.878940  170.053742
# 2       -83.764991  173.367191
# 3       -85.236372  176.703016
# 4       -85.827949 -179.949903
# ...            ...         ...
# 52555   -68.725457  151.345160
# 52556   -71.001501  154.338568
# 52557   -73.264218  157.400817
# 52558   -75.506650  160.527038
# 52559   -77.716959  163.711070
#
# [52560 rows x 10 columns]

# %%
isteps,datavoids,idates=imp.void_identifier(tmx_inc,'Ig')
# Out:
# new_void_at: 2018-01-12 07:20:00
# at index 1628
# 66
# new_void_at: 2018-01-30 07:20:00
# at index 4220
# 67
# new_void_at: 2018-04-17 06:30:00
# at index 15303
# 75
# new_void_at: 2018-06-15 06:10:00
# at index 23797
# 79
# new_void_at: 2018-07-19 06:20:00
# at index 28694
# 78
# new_void_at: 2018-08-12 06:30:00
# at index 32151
# 76
# new_void_at: 2018-11-14 06:50:00
# at index 45689
# 67
# new_void_at: 2018-12-21 07:10:00
# at index 51019

# %%
isteps
# Out:
# [1628, 4220, 15303, 23797, 28694, 32151, 45689, 51019]

# %%
idates
# Out:
# ['2018-01-12 07:20:00',
#  '2018-01-30 07:20:00',
#  '2018-04-17 06:30:00',
#  '2018-06-15 06:10:00',
#  '2018-07-19 06:20:00',
#  '2018-08-12 06:30:00',
#  '2018-11-14 06:50:00',
#  '2018-12-21 07:10:00']

# %%
datavoids
# Out:
# [66, 67, 75, 79, 78, 76, 67, 66]

# %%
tmx_inc=pd.read_csv(path_archivo+nombre_archivo,index_col=0,parse_dates=True)
tmx_inc
# Out:
#                       Ib   Ig     to     RH         P     WS     WD  \
# time
# 2018-01-01 00:00:00  0.0  0.0  18.70  36.34  87864.11  1.422  316.0
# 2018-01-01 00:10:00  0.0  0.0  18.95  35.29  87876.37  1.008  283.7
# 2018-01-01 00:20:00  0.0  0.0  18.94  35.43  87888.64  1.565  326.0
# 2018-01-01 00:30:00  0.0  0.0  18.77  35.89  87887.21  2.175  354.5
# 2018-01-01 00:40:00  0.0  0.0  18.81  36.34  87886.91  1.902  348.0
# ...                  ...  ...    ...    ...       ...    ...    ...
# 2018-12-31 23:10:00  0.0  0.0  18.51  47.29  87484.32  1.715  332.2
# 2018-12-31 23:20:00  0.0  0.0  18.26  48.02  87470.70  1.703  320.5
# 2018-12-31 23:30:00  0.0  0.0  18.39  46.84  87455.03  2.887  335.7
# 2018-12-31 23:40:00  0.0  0.0  17.99  47.85  87470.02  1.528  358.8
# 2018-12-31 23:50:00  0.0  0.0  17.75  49.65  87467.29  0.598  322.3
#
#                      alturasolar     azimuth
# time
# 2018-01-01 00:00:00   -79.806160  166.773196
# 2018-01-01 00:10:00   -81.878940  170.053742
# 2018-01-01 00:20:00   -83.764991  173.367191
# 2018-01-01 00:30:00   -85.236372  176.703016
# 2018-01-01 00:40:00   -85.827949 -179.949903
# ...                          ...         ...
# 2018-12-31 23:10:00   -68.725457  151.345160
# 2018-12-31 23:20:00   -71.001501  154.338568
# 2018-12-31 23:30:00   -73.264218  157.400817
# 2018-12-31 23:40:00   -75.506650  160.527038
# 2018-12-31 23:50:00   -77.716959  163.711070
#
# [52560 rows x 9 columns]

# %%
i=2 #hasta 7
fecha1=parse(idates[i])-pd.Timedelta('5D')
fecha2=parse(idates[i])+pd.Timedelta('2D')
plt.figure(figsize=(20,10))
plt.plot(tmx_inc.Ig[fecha1:fecha2])

# %% [markdown]
# ## Train the data

# %%
fecha1=parse(idates[i])-pd.Timedelta('5D')
fecha2=parse(idates[i])
train_data=tmx_inc.Ig.loc[fecha1:fecha2]
train_data = train_data.asfreq(pd.infer_freq(train_data.index))
my_order = (0,0,0)
my_seasonal_order = (0, 1,1, 144)
# define model

# %%
model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order)
start = time()
model_fit = model.fit()
end = time()
print('training_time:', end-start)
# Out:
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.05727D+00    |proj g|=  1.62227D-01
#  This problem is unconstrained.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/7n/c_cvng9j735c5pvm2v5k2tdh0000gp/T/ipykernel_27132/528272370.py in <module>
#       1 model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order)
#       2 start = time()
# ----> 3 model_fit = model.fit()
#       4 end = time()
#       5 print('training_time:', end-start)
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     688                 flags['hessian_method'] = optim_hessian
#     689             fargs = (flags,)
# --> 690             mlefit = super(MLEModel, self).fit(start_params, method=method,
#     691                                                fargs=fargs,
#     692                                                maxiter=maxiter,
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     517         warn_convergence = kwargs.pop('warn_convergence', True)
#     518         optimizer = Optimizer()
# --> 519         xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     520                                                        fargs, kwargs,
#     521                                                        hessian=hess,
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     222
#     223         func = fit_funcs[method]
# --> 224         xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     225                             disp=disp, maxiter=maxiter, callback=callback,
#     226                             retall=retall, full_output=full_output,
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     627         func = f
#     628
# --> 629     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     630                                      callback=callback, args=fargs,
#     631                                      bounds=bounds, disp=disp,
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     195             'maxls': maxls}
#     196
# --> 197     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                            **opts)
#     199     d = {'grad': res['jac'],
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     266             self._update_x_impl(x)
#     267         self._update_fun()
# --> 268         self._update_grad()
#     269         return self.f, self.g
#     270
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_grad(self)
#     236     def _update_grad(self):
#     237         if not self.g_updated:
# --> 238             self._update_grad_impl()
#     239             self.g_updated = True
#     240
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_grad()
#     153                 self._update_fun()
#     154                 self.ngev += 1
# --> 155                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     156                                            **finite_diff_options)
#     157
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     484
#     485         if sparsity is None:
# --> 486             return _dense_difference(fun_wrapped, x0, f0, h,
#     487                                      use_one_sided, method)
#     488         else:
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     555             x = x0 + h_vecs[i]
#     556             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 557             df = fun(x) - f0
#     558         elif method == '3-point' and use_one_sided[i]:
#     559             x1 = x0 + h_vecs[i]
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in fun_wrapped(x)
#     435
#     436     def fun_wrapped(x):
# --> 437         f = np.atleast_1d(fun(x, *args, **kwargs))
#     438         if f.ndim > 1:
#     439             raise RuntimeError("`fun` return value has "
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/base/model.py in f(params, *args)
#     499
#     500         def f(params, *args):
# --> 501             return -self.loglike(params, *args) / nobs
#     502
#     503         if method == 'newton':
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/mlemodel.py in loglike(self, params, *args, **kwargs)
#     923             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     924
# --> 925         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     926
#     927         # Koopman, Shephard, and Doornik recommend maximizing the average
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/kalman_filter.py in loglike(self, **kwargs)
#     981         kwargs.setdefault('conserve_memory',
#     982                           MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# --> 983         kfilter = self._filter(**kwargs)
#     984         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     985                                         self.loglikelihood_burn)
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     904
#     905         # Run the filter
# --> 906         kfilter()
#     907
#     908         return kfilter
#
# KeyboardInterrupt:

# %%
model_fit.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/7n/c_cvng9j735c5pvm2v5k2tdh0000gp/T/ipykernel_46795/4184862335.py in <module>
# ----> 1 model_fit.summary()
#
# NameError: name 'model_fit' is not defined

# %%
predictions = model_fit.forecast(steps=datavoids[i])
predictions = np.array(predictions)

# %%
plt.plot(predictions)

# %%
nombres=['time','Ib','Ig','To','RH','WS','WD','P','Eg']
imputed=imp.exporta(path_archivo+nombre_archivo,predictions,isteps[i],datavoids[i],nombres)
# Out:
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
#Falta ponerle el exporta, y hacerlo un loop. Despu'es hacer EPW, simular y sacar m'etricas

# %%
plt.figure(figsize=(20,10))
plt.plot(imputed.Ig.loc[parse(idates[i])-pd.Timedelta('7D'):parse(idates[i])+pd.Timedelta('2D')])

# %% [markdown]
# ## Imputation cycle

# %% [markdown]
# 3 years for training 2 years for testing with 1H sample

# %%
path_imputed_file='../../01_weather_data/03_imputing_process/02_imputed_data/Tmx_SARIMA_mae_0_1_0_0_1_1.csv'
tmx_inc.to_csv(path_imputed_file) #Export the incomplete data to what it will become the imputed data
for i in range(len(idates)):
    fecha1=parse(idates[i])-pd.Timedelta('5D')
    fecha2=parse(idates[i])
    train_data=tmx_inc.Ig.loc[fecha1:fecha2]
    train_data = train_data.asfreq(pd.infer_freq(train_data.index))
    my_order = (0,1,0)
    my_seasonal_order =(0, 1, 1, 144) #(2, 0, 1, 144)
    model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order)
    start = time()
    model_fit = model.fit()
    end = time()
    print('training_time:', end-start)
    print(model_fit.summary())
    predictions = model_fit.forecast(steps=datavoids[i]) #Hago predicci'on
    predictions = np.array(predictions)
    nombres=['time','Ib','Ig','To','RH','WS','WD','P','Eg']
    #Lo meto en el archivo con los indices correspondientes
    imputed=imp.exporta(path_imputed_file,'Ig',predictions,isteps[i],datavoids[i],nombres,path_exported_file=path_imputed_file,save=True)
    plt.figure(figsize=(20,10))
    plt.plot(imputed.Ig.loc[parse(idates[i])-pd.Timedelta('1D'):parse(idates[i])+pd.Timedelta('2D')])
    plt.show()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.30767D+00    |proj g|=  4.04547D-01
#  This problem is unconstrained.
# At iterate    5    f=  2.16294D+00    |proj g|=  5.60071D-03
#
# At iterate   10    f=  2.16125D+00    |proj g|=  1.05408D-03
#
# At iterate   15    f=  2.16111D+00    |proj g|=  9.98328D-04
#
# At iterate   20    f=  2.16108D+00    |proj g|=  2.20800D-04
#
# At iterate   25    f=  2.16108D+00    |proj g|=  5.91118D-05
#
# At iterate   30    f=  2.16107D+00    |proj g|=  2.19827D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     31     44      1     0     0   2.195D-05   2.161D+00
#   F =   2.1610744004589213
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# training_time: 416.8497049808502
#                                        SARIMAX Results
# =============================================================================================
# Dep. Variable:                                    Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, 0)x(0, 1, [1], 144)   Log Likelihood               -1558.135
# Date:                               Wed, 08 Dec 2021   AIC                           3120.269
# Time:                                       13:26:44   BIC                           3128.982
# Sample:                                   01-07-2018   HQIC                          3123.667
#                                         - 01-12-2018
# Covariance Type:                                 opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.9973      7.623     -0.131      0.896     -15.938      13.944
# sigma2         8.8608     67.381      0.132      0.895    -123.204     140.926
# ===================================================================================
# Ljung-Box (L1) (Q):                   8.84   Jarque-Bera (JB):               660.39
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.58   Skew:                             0.06
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.71671D+00    |proj g|=  5.37064D-01
#  This problem is unconstrained.
# At iterate    5    f=  4.51936D+00    |proj g|=  5.88621D-04
#
# At iterate   10    f=  4.51793D+00    |proj g|=  1.85172D-04
#
# At iterate   15    f=  4.51783D+00    |proj g|=  1.19361D-04
#
# At iterate   20    f=  4.51779D+00    |proj g|=  1.91812D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     24     28      1     0     0   6.372D-06   4.518D+00
#   F =   4.5177876615844079
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# training_time: 366.70547580718994
#                                        SARIMAX Results
# =============================================================================================
# Dep. Variable:                                    Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, 0)x(0, 1, [1], 144)   Log Likelihood               -3257.325
# Date:                               Wed, 08 Dec 2021   AIC                           6518.650
# Time:                                       13:32:53   BIC                           6527.362
# Sample:                                   01-25-2018   HQIC                          6522.047
#                                         - 01-30-2018
# Covariance Type:                                 opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.9880      1.606     -0.615      0.538      -4.135       2.159
# sigma2      3303.4626   5272.940      0.626      0.531   -7031.309    1.36e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                  33.98   Jarque-Bera (JB):              1815.58
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.29   Skew:                            -0.85
# Prob(H) (two-sided):                  0.00   Kurtosis:                        11.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.86991D+00    |proj g|=  1.02465D+00
#  This problem is unconstrained.
# At iterate    5    f=  4.31889D+00    |proj g|=  1.40906D-02
#
# At iterate   10    f=  4.26691D+00    |proj g|=  1.83636D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     11     12      1     0     0   7.903D-06   4.267D+00
#   F =   4.2669082470555644
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# training_time: 179.40825486183167
#                                        SARIMAX Results
# =============================================================================================
# Dep. Variable:                                    Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, 0)x(0, 1, [1], 144)   Log Likelihood               -3076.441
# Date:                               Wed, 08 Dec 2021   AIC                           6156.882
# Time:                                       13:35:53   BIC                           6165.594
# Sample:                                   04-12-2018   HQIC                          6160.279
#                                         - 04-17-2018
# Covariance Type:                                 opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.9819      0.797     -1.232      0.218      -2.544       0.581
# sigma2      1771.6207   1403.759      1.262      0.207    -979.697    4522.938
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.41   Jarque-Bera (JB):             14380.97
# Prob(Q):                              0.52   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.18   Skew:                             0.25
# Prob(H) (two-sided):                  0.00   Kurtosis:                        27.47
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.02550D+00    |proj g|=  4.67615D-01
#  This problem is unconstrained.
# At iterate    5    f=  4.86706D+00    |proj g|=  1.82871D-03
#
# At iterate   10    f=  4.86605D+00    |proj g|=  5.38933D-04
#
# At iterate   15    f=  4.86600D+00    |proj g|=  4.29655D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     17     21      1     0     0   1.139D-06   4.866D+00
#   F =   4.8660027568902091
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# training_time: 291.56765699386597
#                                        SARIMAX Results
# =============================================================================================
# Dep. Variable:                                    Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, 0)x(0, 1, [1], 144)   Log Likelihood               -3508.388
# Date:                               Wed, 08 Dec 2021   AIC                           7020.776
# Time:                                       13:40:47   BIC                           7029.488
# Sample:                                   06-10-2018   HQIC                          7024.174
#                                         - 06-15-2018
# Covariance Type:                                 opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.9060      0.133     -6.836      0.000      -1.166      -0.646
# sigma2      8558.0183   1053.913      8.120      0.000    6492.386    1.06e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                  61.63   Jarque-Bera (JB):              2832.55
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.48   Skew:                             0.26
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.87190D+00    |proj g|=  4.91229D-01
#
# At iterate    5    f=  4.63218D+00    |proj g|=  4.58698D-03
#
# At iterate   10    f=  4.61429D+00    |proj g|=  6.13243D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     10     11      1     0     0   6.132D-06   4.614D+00
#   F =   4.6142916334526536
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# training_time: 179.3895878791809
#                                        SARIMAX Results
# =============================================================================================
# Dep. Variable:                                    Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, 0)x(0, 1, [1], 144)   Log Likelihood               -3326.904
# Date:                               Wed, 08 Dec 2021   AIC                           6657.809
# Time:                                       13:43:47   BIC                           6666.521
# Sample:                                   07-14-2018   HQIC                          6661.206
#                                         - 07-19-2018
# Covariance Type:                                 opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.9836      0.921     -1.068      0.286      -2.789       0.822
# sigma2      4237.1259   3846.710      1.101      0.271   -3302.287    1.18e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.57   Jarque-Bera (JB):             10187.01
# Prob(Q):                              0.06   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.10   Skew:                            -0.69
# Prob(H) (two-sided):                  0.00   Kurtosis:                        23.56
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.69590D+00    |proj g|=  4.02761D-02
#
# At iterate    5    f=  4.68646D+00    |proj g|=  4.01863D-02
#
# At iterate   10    f=  4.56196D+00    |proj g|=  3.43933D-03
#
# At iterate   15    f=  4.53034D+00    |proj g|=  1.19811D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     18     31      1     0     0   5.624D-07   4.530D+00
#   F =   4.5301712951053261
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# training_time: 391.75599694252014
#                                        SARIMAX Results
# =============================================================================================
# Dep. Variable:                                    Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, 0)x(0, 1, [1], 144)   Log Likelihood               -3266.254
# Date:                               Wed, 08 Dec 2021   AIC                           6536.507
# Time:                                       13:50:21   BIC                           6545.219
# Sample:                                   08-07-2018   HQIC                          6539.905
#                                         - 08-12-2018
# Covariance Type:                                 opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.3356      0.039     -8.505      0.000      -0.413      -0.258
# sigma2      4884.3822     71.934     67.901      0.000    4743.395    5025.370
# ===================================================================================
# Ljung-Box (L1) (Q):                  81.16   Jarque-Bera (JB):             22672.25
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.69   Skew:                            -1.08
# Prob(H) (two-sided):                  0.00   Kurtosis:                        33.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.19436D+00    |proj g|=  5.95953D-02
#
# At iterate    5    f=  4.06918D+00    |proj g|=  8.81949D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      9     14      1     0     0   5.071D-06   4.069D+00
#   F =   4.0686361123613830
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# training_time: 162.00992894172668
#                                        SARIMAX Results
# =============================================================================================
# Dep. Variable:                                    Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, 0)x(0, 1, [1], 144)   Log Likelihood               -2933.487
# Date:                               Wed, 08 Dec 2021   AIC                           5870.973
# Time:                                       13:53:04   BIC                           5879.685
# Sample:                                   11-09-2018   HQIC                          5874.371
#                                         - 11-14-2018
# Covariance Type:                                 opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.3962      0.039    -10.096      0.000      -0.473      -0.319
# sigma2      1514.9382     29.150     51.971      0.000    1457.806    1572.070
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.83   Jarque-Bera (JB):              9222.39
# Prob(Q):                              0.09   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.52   Skew:                            -0.70
# Prob(H) (two-sided):                  0.00   Kurtosis:                        22.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.63698D+00    |proj g|=  2.30092D+00
#  This problem is unconstrained.
# At iterate    5    f=  4.19887D+00    |proj g|=  4.30229D-02
#
# At iterate   10    f=  4.03976D+00    |proj g|=  1.49608D-04
#
# At iterate   15    f=  4.03975D+00    |proj g|=  5.02245D-05
#
# At iterate   20    f=  4.03973D+00    |proj g|=  1.70058D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     21     22      1     0     0   5.927D-06   4.040D+00
#   F =   4.0397328111150257
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# training_time: 242.6849069595337
#                                        SARIMAX Results
# =============================================================================================
# Dep. Variable:                                    Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, 0)x(0, 1, [1], 144)   Log Likelihood               -2912.647
# Date:                               Wed, 08 Dec 2021   AIC                           5829.295
# Time:                                       13:57:08   BIC                           5838.007
# Sample:                                   12-16-2018   HQIC                          5832.692
#                                         - 12-21-2018
# Covariance Type:                                 opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.9941      2.743     -0.362      0.717      -6.371       4.383
# sigma2       988.7339   2706.266      0.365      0.715   -4315.449    6292.917
# ===================================================================================
# Ljung-Box (L1) (Q):                  42.18   Jarque-Bera (JB):              7920.52
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.07   Skew:                            -0.03
# Prob(H) (two-sided):                  0.00   Kurtosis:                        21.17
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                        SARIMAX Results
# =============================================================================================
# Dep. Variable:                                    Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, 0)x(0, 1, [1], 144)   Log Likelihood               -2912.647
# Date:                               Wed, 08 Dec 2021   AIC                           5829.295
# Time:                                       13:57:50   BIC                           5838.007
# Sample:                                   12-16-2018   HQIC                          5832.692
#                                         - 12-21-2018
# Covariance Type:                                 opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.9941      2.743     -0.362      0.717      -6.371       4.383
# sigma2       988.7339   2706.266      0.365      0.715   -4315.449    6292.917
# ===================================================================================
# Ljung-Box (L1) (Q):                  42.18   Jarque-Bera (JB):              7920.52
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.07   Skew:                            -0.03
# Prob(H) (two-sided):                  0.00   Kurtosis:                        21.17
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
imputed_csv=pd.read_csv('../../01_weather_data/03_imputing_process/02_imputed_data/Tmx_SARIMA_mae_0_1_0_0_1_1.csv',index_col=0,parse_dates=True)
complete=pd.read_csv('../../01_weather_data/03_imputing_process/01_test_data/base_temixco.csv',index_col=0,parse_dates=True)
complete['mae']=np.abs(imputed_csv.Ig-complete.Ig)

# %%
idates
# Out:
# ['2018-01-12 07:20:00',
#  '2018-01-30 07:20:00',
#  '2018-04-17 06:30:00',
#  '2018-06-15 06:10:00',
#  '2018-07-19 06:20:00',
#  '2018-08-12 06:30:00',
#  '2018-11-14 06:50:00',
#  '2018-12-21 07:10:00']

# %%
dias=['2018-01-12',
 '2018-01-30',
 '2018-04-17',
 '2018-06-15',
 '2018-07-19',
 '2018-08-12',
 '2018-11-14',
 '2018-12-21']

# %%
meyear=complete.mae.resample('D').mean()
for i in range(len(idates)):
    fig,ax=plt.subplots(figsize=(20,5))
    print('mae_day:',meyear[dias[i]])
    ax.plot(imputed.Ig.loc[dias[i]],'g.-',label='imputado')
    ax.plot(complete.Ig.loc[dias[i]],'k-',label='real')
    ax.plot(complete.mae.loc[dias[i]],'r.',label='mae')
    ax.legend()
    plt.show()
# Out:
# mae_day: 10.763834789105992
# mae_day: 57.7680816165134
# mae_day: 19.218591451363437
# mae_day: 123.95833941987595
# mae_day: 48.61814987960489
# mae_day: 148.6053349686224
# mae_day: 155.0230279565667
# mae_day: 17.287949549263793

# %%
calplot.calplot(complete.Ig)
# Out:
# (<Figure size 900x122.4 with 2 Axes>,
#  array([<AxesSubplot:ylabel='2018'>], dtype=object))

# %%
#errores con sarima 000 011
01-12 10.763741228846762
01-30 57.735961897202664
04-17 17.752497086218725
06-15 112.76277897120623
07-19 48.65611964302928
08-12 148.00907175398788
11-14 156.3850152940706
12-21 17.311225530032065 
#_________________________
#errores con sarima 010 011
01-12
01-30
04-17
06-15
07-19
08-12
11-14
12-21
