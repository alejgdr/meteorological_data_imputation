# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import timedelta
from pandas.plotting import register_matplotlib_converters
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from time import time
from dateutil.parser import parse
import impute as imp
import calplot

# %% [markdown]
# # Importo datos de anio incompleto

# %%
path_archivo='../../01_weather_data/03_imputing_process/01_test_data/'#camino para llegar a archivo a importar
nombre_archivo='tmx_incomplete_solar_angles.csv'# archivo a importar
tmx_inc=pd.read_csv(path_archivo+nombre_archivo,parse_dates=True)
tmx_inc
# Out:
#                       time   Ib   Ig     to     RH         P  alturasolar  \
# 0      2018-01-01 00:00:00  0.0  0.0  18.70  36.34  87864.11   -79.806160
# 1      2018-01-01 00:10:00  0.0  0.0  18.95  35.29  87876.37   -81.878940
# 2      2018-01-01 00:20:00  0.0  0.0  18.94  35.43  87888.64   -83.764991
# 3      2018-01-01 00:30:00  0.0  0.0  18.77  35.89  87887.21   -85.236372
# 4      2018-01-01 00:40:00  0.0  0.0  18.81  36.34  87886.91   -85.827949
# ...                    ...  ...  ...    ...    ...       ...          ...
# 52555  2018-12-31 23:10:00  0.0  0.0  18.51  47.29  87484.32   -68.725457
# 52556  2018-12-31 23:20:00  0.0  0.0  18.26  48.02  87470.70   -71.001501
# 52557  2018-12-31 23:30:00  0.0  0.0  18.39  46.84  87455.03   -73.264218
# 52558  2018-12-31 23:40:00  0.0  0.0  17.99  47.85  87470.02   -75.506650
# 52559  2018-12-31 23:50:00  0.0  0.0  17.75  49.65  87467.29   -77.716959
#
#           azimuth
# 0      166.773196
# 1      170.053742
# 2      173.367191
# 3      176.703016
# 4     -179.949903
# ...           ...
# 52555  151.345160
# 52556  154.338568
# 52557  157.400817
# 52558  160.527038
# 52559  163.711070
#
# [52560 rows x 8 columns]

# %%
isteps,datavoids,idates=imp.void_identifier(tmx_inc,'Ig')
# Out:
# new_void_at: 2018-01-30 07:20:00
# at index 4220
# 67
# new_void_at: 2018-03-29 06:40:00
# at index 12568
# 73
# new_void_at: 2018-06-15 06:10:00
# at index 23797
# 79
# new_void_at: 2018-06-27 06:10:00
# at index 25525
# 79
# new_void_at: 2018-07-28 06:20:00
# at index 29990
# 78
# new_void_at: 2018-08-12 06:30:00
# at index 32151
# 76
# new_void_at: 2018-10-05 06:40:00
# at index 39928
# 70
# new_void_at: 2018-11-14 06:50:00
# at index 45689

# %%
isteps
# Out:
# [4220, 12568, 23797, 25525, 29990, 32151, 39928, 45689]

# %%
idates
# Out:
# ['2018-01-30 07:20:00',
#  '2018-03-29 06:40:00',
#  '2018-06-15 06:10:00',
#  '2018-06-27 06:10:00',
#  '2018-07-28 06:20:00',
#  '2018-08-12 06:30:00',
#  '2018-10-05 06:40:00',
#  '2018-11-14 06:50:00']

# %%
datavoids
# Out:
# [67, 73, 79, 79, 78, 76, 70, 67]

# %%
tmx_inc=pd.read_csv(path_archivo+nombre_archivo,index_col=0,parse_dates=True)
tmx_inc
# Out:
#                       Ib   Ig     to     RH         P  alturasolar     azimuth
# time
# 2018-01-01 00:00:00  0.0  0.0  18.70  36.34  87864.11   -79.806160  166.773196
# 2018-01-01 00:10:00  0.0  0.0  18.95  35.29  87876.37   -81.878940  170.053742
# 2018-01-01 00:20:00  0.0  0.0  18.94  35.43  87888.64   -83.764991  173.367191
# 2018-01-01 00:30:00  0.0  0.0  18.77  35.89  87887.21   -85.236372  176.703016
# 2018-01-01 00:40:00  0.0  0.0  18.81  36.34  87886.91   -85.827949 -179.949903
# ...                  ...  ...    ...    ...       ...          ...         ...
# 2018-12-31 23:10:00  0.0  0.0  18.51  47.29  87484.32   -68.725457  151.345160
# 2018-12-31 23:20:00  0.0  0.0  18.26  48.02  87470.70   -71.001501  154.338568
# 2018-12-31 23:30:00  0.0  0.0  18.39  46.84  87455.03   -73.264218  157.400817
# 2018-12-31 23:40:00  0.0  0.0  17.99  47.85  87470.02   -75.506650  160.527038
# 2018-12-31 23:50:00  0.0  0.0  17.75  49.65  87467.29   -77.716959  163.711070
#
# [52560 rows x 7 columns]

# %%
i=2 #hasta 7
fecha1=parse(idates[i])-pd.Timedelta('5D')
fecha2=parse(idates[i])
plt.figure(figsize=(20,10))
plt.plot(tmx_inc.Ig[fecha1:fecha2])

# %% [markdown]
# ## Train the data

# %%
fecha1=parse(idates[i])-pd.Timedelta('5D')
fecha2=parse(idates[i])
train_data=tmx_inc.Ig.loc[fecha1:fecha2]
train_data = train_data.asfreq(pd.infer_freq(train_data.index))
my_order = (0,0,0)
my_seasonal_order = (0, 1,1, 144)
# define model

# %%
model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order)
start = time()
model_fit = model.fit()
end = time()
print('training_time:', end-start)
# Out:
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.05727D+00    |proj g|=  1.62227D-01
#  This problem is unconstrained.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/7n/c_cvng9j735c5pvm2v5k2tdh0000gp/T/ipykernel_27132/528272370.py in <module>
#       1 model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order)
#       2 start = time()
# ----> 3 model_fit = model.fit()
#       4 end = time()
#       5 print('training_time:', end-start)
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     688                 flags['hessian_method'] = optim_hessian
#     689             fargs = (flags,)
# --> 690             mlefit = super(MLEModel, self).fit(start_params, method=method,
#     691                                                fargs=fargs,
#     692                                                maxiter=maxiter,
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     517         warn_convergence = kwargs.pop('warn_convergence', True)
#     518         optimizer = Optimizer()
# --> 519         xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     520                                                        fargs, kwargs,
#     521                                                        hessian=hess,
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     222
#     223         func = fit_funcs[method]
# --> 224         xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     225                             disp=disp, maxiter=maxiter, callback=callback,
#     226                             retall=retall, full_output=full_output,
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     627         func = f
#     628
# --> 629     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     630                                      callback=callback, args=fargs,
#     631                                      bounds=bounds, disp=disp,
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     195             'maxls': maxls}
#     196
# --> 197     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     198                            **opts)
#     199     d = {'grad': res['jac'],
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     358             # until the completion of the current minimization iteration.
#     359             # Overwrite f and g:
# --> 360             f, g = func_and_grad(x)
#     361         elif task_str.startswith(b'NEW_X'):
#     362             # new iteration
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     266             self._update_x_impl(x)
#     267         self._update_fun()
# --> 268         self._update_grad()
#     269         return self.f, self.g
#     270
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in _update_grad(self)
#     236     def _update_grad(self):
#     237         if not self.g_updated:
# --> 238             self._update_grad_impl()
#     239             self.g_updated = True
#     240
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in update_grad()
#     153                 self._update_fun()
#     154                 self.ngev += 1
# --> 155                 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     156                                            **finite_diff_options)
#     157
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     484
#     485         if sparsity is None:
# --> 486             return _dense_difference(fun_wrapped, x0, f0, h,
#     487                                      use_one_sided, method)
#     488         else:
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     555             x = x0 + h_vecs[i]
#     556             dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 557             df = fun(x) - f0
#     558         elif method == '3-point' and use_one_sided[i]:
#     559             x1 = x0 + h_vecs[i]
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/_numdiff.py in fun_wrapped(x)
#     435
#     436     def fun_wrapped(x):
# --> 437         f = np.atleast_1d(fun(x, *args, **kwargs))
#     438         if f.ndim > 1:
#     439             raise RuntimeError("`fun` return value has "
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     132             # Overwriting results in undefined behaviour because
#     133             # fun(self.x) will change self.x, with the two no longer linked.
# --> 134             return fun(np.copy(x), *args)
#     135
#     136         def update_fun():
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/base/model.py in f(params, *args)
#     499
#     500         def f(params, *args):
# --> 501             return -self.loglike(params, *args) / nobs
#     502
#     503         if method == 'newton':
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/mlemodel.py in loglike(self, params, *args, **kwargs)
#     923             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     924
# --> 925         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     926
#     927         # Koopman, Shephard, and Doornik recommend maximizing the average
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/kalman_filter.py in loglike(self, **kwargs)
#     981         kwargs.setdefault('conserve_memory',
#     982                           MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD)
# --> 983         kfilter = self._filter(**kwargs)
#     984         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     985                                         self.loglikelihood_burn)
#
# ~/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     904
#     905         # Run the filter
# --> 906         kfilter()
#     907
#     908         return kfilter
#
# KeyboardInterrupt:

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   SARIMAX Results
# ===================================================================================
# Dep. Variable:                          Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, [1], 144)   Log Likelihood               -3615.446
# Date:                     Tue, 19 Oct 2021   AIC                           7234.891
# Time:                             11:51:29   BIC                           7243.607
# Sample:                         06-10-2018   HQIC                          7238.290
#                               - 06-15-2018
# Covariance Type:                       opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.4798      0.036    -13.496      0.000      -0.550      -0.410
# sigma2      1.574e+04    545.735     28.842      0.000    1.47e+04    1.68e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                 214.55   Jarque-Bera (JB):              1065.96
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.46   Skew:                            -0.95
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
predictions = model_fit.forecast(steps=datavoids[i])
predictions = np.array(predictions)

# %%
plt.plot(predictions)

# %%
nombres=['time','Ib','Ig','To','RH','WS','WD','P','Eg']
imputed=imp.exporta(path_archivo+nombre_archivo,predictions,isteps[i],datavoids[i],nombres)
# Out:
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
#Falta ponerle el exporta, y hacerlo un loop. Despu'es hacer EPW, simular y sacar m'etricas

# %%
plt.figure(figsize=(20,10))
plt.plot(imputed.Ig.loc[parse(idates[i])-pd.Timedelta('7D'):parse(idates[i])+pd.Timedelta('2D')])

# %% [markdown]
# ## Imputation cycle

# %% [markdown]
# 3 years for training 2 years for testing with 1H sample

# %%
path_imputed_file='../../01_weather_data/03_imputing_process/02_imputed_data/Tmx_SARIMA_0_1_1.csv'
tmx_inc.to_csv(path_imputed_file) #Export the incomplete data to what it will be the imputed data
for i in range(len(idates)):
    fecha1=parse(idates[i])-pd.Timedelta('5D')
    fecha2=parse(idates[i])
    train_data=tmx_inc.Ig.loc[fecha1:fecha2]
    train_data = train_data.asfreq(pd.infer_freq(train_data.index))
    my_order = (0,0,0)
    my_seasonal_order =(0, 1, 1, 144) #(2, 0, 1, 144)
    model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order)
    start = time()
    model_fit = model.fit()
    end = time()
    print('training_time:', end-start)
    print(model_fit.summary())
    predictions = model_fit.forecast(steps=datavoids[i]) #Hago predicci'on
    predictions = np.array(predictions)
    nombres=['time','Ib','Ig','To','RH','WS','WD','P','Eg']
    #Lo meto en el archivo con los indices correspondientes
    imputed=imp.exporta(path_imputed_file,'Ig',predictions,isteps[i],datavoids[i],nombres,path_exported_file=path_imputed_file,save=True)
    plt.figure(figsize=(20,10))
    plt.plot(imputed.Ig.loc[parse(idates[i])-pd.Timedelta('1D'):parse(idates[i])+pd.Timedelta('2D')])
    plt.show()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.73260D+00    |proj g|=  3.16156D-01
#  This problem is unconstrained.
# At iterate    5    f=  4.60476D+00    |proj g|=  4.46545D-03
#
# At iterate   10    f=  4.60363D+00    |proj g|=  9.74539D-04
#
# At iterate   15    f=  4.60322D+00    |proj g|=  8.32252D-05
#
# At iterate   20    f=  4.60318D+00    |proj g|=  9.86189D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     20     25      1     0     0   9.862D-06   4.603D+00
#   F =   4.6031818005944585
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# training_time: 186.2981150150299
#                                   SARIMAX Results
# ===================================================================================
# Dep. Variable:                          Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, [1], 144)   Log Likelihood               -3318.894
# Date:                     Tue, 19 Oct 2021   AIC                           6641.788
# Time:                             12:24:10   BIC                           6650.504
# Sample:                         01-25-2018   HQIC                          6645.187
#                               - 01-30-2018
# Covariance Type:                       opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.9897      1.897     -0.522      0.602      -4.707       2.728
# sigma2      4008.0393   7553.493      0.531      0.596   -1.08e+04    1.88e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                 201.29   Jarque-Bera (JB):               812.12
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.34   Skew:                             0.22
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.22880D+00    |proj g|=  3.23729D-02
#  This problem is unconstrained.
# At iterate    5    f=  3.22539D+00    |proj g|=  5.96400D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      7      9      1     0     0   4.688D-06   3.225D+00
#   F =   3.2253873092004222
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# training_time: 86.28318381309509
#                                   SARIMAX Results
# ===================================================================================
# Dep. Variable:                          Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, [1], 144)   Log Likelihood               -2325.504
# Date:                     Tue, 19 Oct 2021   AIC                           4655.008
# Time:                             12:25:37   BIC                           4663.724
# Sample:                         03-24-2018   HQIC                          4658.407
#                               - 03-29-2018
# Covariance Type:                       opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.1960      0.039     -5.047      0.000      -0.272      -0.120
# sigma2       186.3316      8.152     22.857      0.000     170.354     202.309
# ===================================================================================
# Ljung-Box (L1) (Q):                 381.27   Jarque-Bera (JB):               209.75
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.82   Skew:                            -0.36
# Prob(H) (two-sided):                  0.16   Kurtosis:                         5.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.05727D+00    |proj g|=  1.62227D-01
#
# At iterate    5    f=  5.02328D+00    |proj g|=  1.98626D-03
#
# At iterate   10    f=  5.01887D+00    |proj g|=  3.53984D-02
#
# At iterate   15    f=  5.01449D+00    |proj g|=  1.20707D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     16     20      1     0     0   2.069D-08   5.014D+00
#   F =   5.0144875235845392
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# training_time: 166.53231382369995
#                                   SARIMAX Results
# ===================================================================================
# Dep. Variable:                          Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, [1], 144)   Log Likelihood               -3615.446
# Date:                     Tue, 19 Oct 2021   AIC                           7234.891
# Time:                             12:28:25   BIC                           7243.607
# Sample:                         06-10-2018   HQIC                          7238.290
#                               - 06-15-2018
# Covariance Type:                       opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.4798      0.036    -13.496      0.000      -0.550      -0.410
# sigma2      1.574e+04    545.735     28.842      0.000    1.47e+04    1.68e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                 214.55   Jarque-Bera (JB):              1065.96
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.46   Skew:                            -0.95
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.46283D+00    |proj g|=  8.50460D-01
#
# At iterate    5    f=  5.16866D+00    |proj g|=  1.77381D-03
#
# At iterate   10    f=  5.16818D+00    |proj g|=  1.41221D-03
#
# At iterate   15    f=  5.16526D+00    |proj g|=  6.07112D-05
#
# At iterate   20    f=  5.16522D+00    |proj g|=  1.23297D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     21     25      1     0     0   4.768D-06   5.165D+00
#   F =   5.1652115936919927
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# training_time: 177.71397972106934
#                                   SARIMAX Results
# ===================================================================================
# Dep. Variable:                          Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, [1], 144)   Log Likelihood               -3724.118
# Date:                     Tue, 19 Oct 2021   AIC                           7452.235
# Time:                             12:31:24   BIC                           7460.951
# Sample:                         06-22-2018   HQIC                          7455.634
#                               - 06-27-2018
# Covariance Type:                       opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.9902      2.513     -0.394      0.694      -5.915       3.935
# sigma2      1.638e+04   4.09e+04      0.400      0.689   -6.39e+04    9.66e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                 406.62   Jarque-Bera (JB):               119.90
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.36   Skew:                             0.22
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.81599D+00    |proj g|=  8.34494D-02
#  This problem is unconstrained.
# At iterate    5    f=  3.75373D+00    |proj g|=  5.64497D-02
#
# At iterate   10    f=  3.74625D+00    |proj g|=  3.93641D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     10     13      1     0     0   3.936D-07   3.746D+00
#   F =   3.7462474542104585
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# training_time: 108.37577795982361
#                                   SARIMAX Results
# ===================================================================================
# Dep. Variable:                          Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, [1], 144)   Log Likelihood               -2701.044
# Date:                     Tue, 19 Oct 2021   AIC                           5406.089
# Time:                             12:33:15   BIC                           5414.805
# Sample:                         07-23-2018   HQIC                          5409.488
#                               - 07-28-2018
# Covariance Type:                       opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.4147      0.025    -16.369      0.000      -0.464      -0.365
# sigma2       660.4323     13.943     47.367      0.000     633.105     687.760
# ===================================================================================
# Ljung-Box (L1) (Q):                 188.14   Jarque-Bera (JB):              9013.16
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.32   Skew:                            -1.19
# Prob(H) (two-sided):                  0.00   Kurtosis:                        22.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.01920D+00    |proj g|=  1.70612D-02
#
# At iterate    5    f=  5.00124D+00    |proj g|=  5.60222D-02
#
# At iterate   10    f=  4.81971D+00    |proj g|=  7.90522D-04
#
# At iterate   15    f=  4.81088D+00    |proj g|=  2.27514D-03
#
# At iterate   20    f=  4.79940D+00    |proj g|=  1.88294D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     20     36      1     0     0   1.883D-08   4.799D+00
#   F =   4.7994000684546059
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# training_time: 231.93969011306763
#                                   SARIMAX Results
# ===================================================================================
# Dep. Variable:                          Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, [1], 144)   Log Likelihood               -3460.367
# Date:                     Tue, 19 Oct 2021   AIC                           6924.735
# Time:                             12:37:09   BIC                           6933.451
# Sample:                         08-07-2018   HQIC                          6928.134
#                               - 08-12-2018
# Covariance Type:                       opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.3265      0.086     -3.787      0.000      -0.496      -0.158
# sigma2      9400.9006    210.064     44.753      0.000    8989.182    9812.619
# ===================================================================================
# Ljung-Box (L1) (Q):                 315.10   Jarque-Bera (JB):              7289.27
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              10.75   Skew:                            -3.57
# Prob(H) (two-sided):                  0.00   Kurtosis:                        18.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.00828D+00    |proj g|=  6.73118D-01
#  This problem is unconstrained.
# At iterate    5    f=  4.75885D+00    |proj g|=  1.93436D-03
#
# At iterate   10    f=  4.73858D+00    |proj g|=  8.56859D-05
#
# At iterate   15    f=  4.73850D+00    |proj g|=  8.86891D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     15     21      1     0     0   8.869D-06   4.739D+00
#   F =   4.7385006801352549
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# training_time: 144.31538486480713
#                                   SARIMAX Results
# ===================================================================================
# Dep. Variable:                          Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, [1], 144)   Log Likelihood               -3416.459
# Date:                     Tue, 19 Oct 2021   AIC                           6836.918
# Time:                             12:39:34   BIC                           6845.634
# Sample:                         09-30-2018   HQIC                          6840.317
#                               - 10-05-2018
# Covariance Type:                       opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.9913      2.927     -0.339      0.735      -6.728       4.745
# sigma2      5660.7852   1.65e+04      0.342      0.732   -2.67e+04    3.81e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                 317.97   Jarque-Bera (JB):              1757.72
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.20   Skew:                            -1.65
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.88
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.82530D+00    |proj g|=  4.14944D-02
#
# At iterate    5    f=  4.78615D+00    |proj g|=  6.68464D-02
#
# At iterate   10    f=  4.62543D+00    |proj g|=  1.33325D-03
#
# At iterate   15    f=  4.61226D+00    |proj g|=  2.47487D-03
#
# At iterate   20    f=  4.60621D+00    |proj g|=  7.85327D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     20     35      1     0     0   7.853D-07   4.606D+00
#   F =   4.6062070478501482
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# training_time: 255.29703831672668
#                                   SARIMAX Results
# ===================================================================================
# Dep. Variable:                          Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, [1], 144)   Log Likelihood               -3321.075
# Date:                     Tue, 19 Oct 2021   AIC                           6646.151
# Time:                             12:43:51   BIC                           6654.866
# Sample:                         11-09-2018   HQIC                          6649.549
#                               - 11-14-2018
# Covariance Type:                       opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.4181      0.085     -4.894      0.000      -0.586      -0.251
# sigma2      5687.6633    163.466     34.794      0.000    5367.277    6008.050
# ===================================================================================
# Ljung-Box (L1) (Q):                 431.02   Jarque-Bera (JB):              3590.91
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              11.46   Skew:                            -3.00
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   SARIMAX Results
# ===================================================================================
# Dep. Variable:                          Ig   No. Observations:                  721
# Model:             SARIMAX(0, 1, [1], 144)   Log Likelihood               -3321.078
# Date:                     Tue, 21 Sep 2021   AIC                           6646.157
# Time:                             18:07:11   BIC                           6654.873
# Sample:                         11-09-2018   HQIC                          6649.556
#                               - 11-14-2018
# Covariance Type:                       opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.S.L144     -0.4181      0.085     -4.894      0.000      -0.586      -0.251
# sigma2      5687.9472    163.482     34.792      0.000    5367.528    6008.366
# ===================================================================================
# Ljung-Box (L1) (Q):                 431.16   Jarque-Bera (JB):              3590.52
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              20.25   Skew:                            -3.00
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.65
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
imputed_csv=pd.read_csv('../../01_weather_data/03_imputing_process/02_imputed_data/Tmx_SARIMA_0_1_1.csv',index_col=0,parse_dates=True)
complete=pd.read_csv('../../01_weather_data/03_imputing_process/01_test_data/base_temixco.csv',index_col=0,parse_dates=True)
complete['mae']=np.abs(imputed_csv.Ig-complete.Ig)

# %%
dias=['2018-03-29',
'2018-01-30',
'2018-06-27',
'2018-06-15',
'2018-07-28',
'2018-08-12',
'2018-10-05',
'2018-11-14']

# %%
meyear=complete.mae.resample('D').mean()
for i in range(len(idates)):
    fig,ax=plt.subplots(figsize=(20,5))
    print('mae_day:',meyear[dias[i]])
    ax.plot(imputed.Ig.loc[dias[i]],'g.-',label='imputado')
    ax.plot(complete.Ig.loc[dias[i]],'k-',label='real')
    ax.plot(complete.mae.loc[dias[i]],'r.',label='mae')
    ax.legend()
    plt.show()
# Out:
# mae_day: 18.380998331786927
# mae_day: 57.735961897202664
# mae_day: 69.47376474928753
# mae_day: 112.76277897120623
# mae_day: 27.18557794035951
# mae_day: 148.00907175398788
# mae_day: 30.457814801166066
# mae_day: 156.3850152940706

# %%
calplot.calplot(complete.Ig)
# Out:
# (<Figure size 900x122.4 with 2 Axes>,
#  array([<AxesSubplot:ylabel='2018'>], dtype=object))

# %%
heio=pd.read_csv(path_imputed_file,index_col=0,parse_dates=True)
calplot.calplot(heio.Ig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/7n/c_cvng9j735c5pvm2v5k2tdh0000gp/T/ipykernel_27018/2239419605.py in <module>
# ----> 1 heio=pd.read_csv(path_imputed_file,index_col=0,parse_dates=True)
#       2 calplot.calplot(heio.Ig)
#
# NameError: name 'path_imputed_file' is not defined

# %% [markdown]
# # Ciclo para script

# %% [markdown]
# fecha1=parse('2018-01-06')-pd.Timedelta('5D')
# fecha2=parse('2018-01-06')
# isteps=144*5
# print(fecha1)
# print(fecha2)
# tmx_inc=pd.read_csv('../../01_weather_data/03_imputing_process/01_test_data/base_temixco.csv',index_col=0,parse_dates=True)
# path_imputed_file='../../01_weather_data/03_imputing_process/02_imputed_data/Tmx_SARIMA_0_1_1_multioneshot.csv'
# tmx_inc.to_csv(path_imputed_file)
# for day in range(360):
#     train_data=tmx_inc.Ig.loc[fecha1:fecha2]
#     train_data = train_data.asfreq(pd.infer_freq(train_data.index))
#     my_order = (0,0,0)
#     my_seasonal_order =(0, 1, 1, 144) #(2, 0, 1, 144)
#     model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order)
#     start = time()
#     model_fit = model.fit()
#     end = time()
#     print('training_time:', end-start)
#     print(model_fit.summary())
#     predictions = model_fit.forecast(steps=144) #Hago predicci'on
#     predictions = np.array(predictions)
#     nombres=['time','Ib','Ig','To','RH','WS','WD','P','Eg']
#     #Lo meto en el archivo con los indices correspondientes
#     imputed=imp.exporta(path_imputed_file,'Ig',predictions,isteps,144,
#                         nombres,path_exported_file=path_imputed_file,save=True)
#     isteps=isteps+144
#     fecha1=fecha1+pd.Timedelta('1D')
#     fecha2=fecha2+pd.Timedelta('1D')
#     print('fecha1:',fecha1)
#     print('fecha2:',fecha2)

# %%
fecha1='2018-1-1'
fecha2='2018-1-7'
path_imputed_file='../../01_weather_data/03_imputing_process/02_imputed_data/Tmx_SARIMA_0_1_1_multioneshot.csv'
tmx_imputed=pd.read_csv(path_imputed_file,index_col=0,parse_dates=True)
fig, ax=plt.subplots(figsize=(20,10))
ax.plot(tmx_imputed.Ig.loc[fecha1:fecha2])
ax.plot(complete.Ig.loc[fecha1:fecha2])

# %%
tmx_iloc=pd.read_csv(path_imputed_file)
tmx_iloc.iloc[144*5]
# Out:
# time    2018-01-06 00:00:00
# Ib                      0.0
# Ig                      0.0
# To                    18.87
# RH                    47.03
# WS                    1.727
# WD                    357.2
# P                  87868.21
# Eg                      0.0
# Name: 720, dtype: object

# %%
from pandas.plotting import register_matplotlib_converters
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from time import time
from dateutil.parser import parse
import impute as imp
tmx_inc=pd.read_csv(path_archivo+nombre_archivo,index_col=0,parse_dates=True)
path_imputed_file='../../01_weather_data/03_imputing_process/02_imputed_data/Tmx_SARIMA_0_1_1_multioneshot.csv'
tmx_inc.to_csv(path_imputed_file) #Export the incomplete data to what it will be the imputed data
for i in range(360):
    fecha1=parse(idates[i])-pd.Timedelta('5D')
    fecha2=parse(idates[i])
    train_data=tmx_inc.Ig.loc[fecha1:fecha2]
    train_data = train_data.asfreq(pd.infer_freq(train_data.index))
    my_order = (0,0,0)
    my_seasonal_order =(0, 1, 1, 144) #(2, 0, 1, 144)
    model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order)
    start = time()
    model_fit = model.fit()
    end = time()
    print('training_time:', end-start)
    print(model_fit.summary())
    predictions = model_fit.forecast(steps=datavoids[i]) #Hago predicci'on
    predictions = np.array(predictions)
    nombres=['time','Ib','Ig','To','RH','WS','WD','P','Eg']
    #Lo meto en el archivo con los indices correspondientes
    imputed=imp.exporta(path_imputed_file,'Ig',predictions,isteps[i]            ,datavoids[i],nombres,path_exported_file=path_imputed_file,save=True)






tmx_inc
# Out:
#                       Ib   Ig     to     RH         P     WS     WD  \
# time
# 2018-01-01 00:00:00  0.0  0.0  18.70  36.34  87864.11  1.422  316.0
# 2018-01-01 00:10:00  0.0  0.0  18.95  35.29  87876.37  1.008  283.7
# 2018-01-01 00:20:00  0.0  0.0  18.94  35.43  87888.64  1.565  326.0
# 2018-01-01 00:30:00  0.0  0.0  18.77  35.89  87887.21  2.175  354.5
# 2018-01-01 00:40:00  0.0  0.0  18.81  36.34  87886.91  1.902  348.0
# ...                  ...  ...    ...    ...       ...    ...    ...
# 2018-12-31 23:10:00  0.0  0.0  18.51  47.29  87484.32  1.715  332.2
# 2018-12-31 23:20:00  0.0  0.0  18.26  48.02  87470.70  1.703  320.5
# 2018-12-31 23:30:00  0.0  0.0  18.39  46.84  87455.03  2.887  335.7
# 2018-12-31 23:40:00  0.0  0.0  17.99  47.85  87470.02  1.528  358.8
# 2018-12-31 23:50:00  0.0  0.0  17.75  49.65  87467.29  0.598  322.3
#
#                      alturasolar     azimuth
# time
# 2018-01-01 00:00:00   -79.806160  166.773196
# 2018-01-01 00:10:00   -81.878940  170.053742
# 2018-01-01 00:20:00   -83.764991  173.367191
# 2018-01-01 00:30:00   -85.236372  176.703016
# 2018-01-01 00:40:00   -85.827949 -179.949903
# ...                          ...         ...
# 2018-12-31 23:10:00   -68.725457  151.345160
# 2018-12-31 23:20:00   -71.001501  154.338568
# 2018-12-31 23:30:00   -73.264218  157.400817
# 2018-12-31 23:40:00   -75.506650  160.527038
# 2018-12-31 23:50:00   -77.716959  163.711070
#
# [52560 rows x 9 columns]
