# %%
import impute as imp
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import calplot 
import datetime 
from pickle import dump,load
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Incomplete data with solar angles added imported without date index

# %%
path_archivo='../../01_weather_data/03_imputing_process/01_test_data/'
nombre_archivo='tmx_incomplete_solar_angles.csv'
tmx_inc=pd.read_csv(path_archivo+nombre_archivo,parse_dates=True)
tmx_inc
# Out:
#                       time   Ib   Ig     to     RH         P     WS     WD  \
# 0      2018-01-01 00:00:00  0.0  0.0  18.70  36.34  87864.11  1.422  316.0
# 1      2018-01-01 00:10:00  0.0  0.0  18.95  35.29  87876.37  1.008  283.7
# 2      2018-01-01 00:20:00  0.0  0.0  18.94  35.43  87888.64  1.565  326.0
# 3      2018-01-01 00:30:00  0.0  0.0  18.77  35.89  87887.21  2.175  354.5
# 4      2018-01-01 00:40:00  0.0  0.0  18.81  36.34  87886.91  1.902  348.0
# ...                    ...  ...  ...    ...    ...       ...    ...    ...
# 52555  2018-12-31 23:10:00  0.0  0.0  18.51  47.29  87484.32  1.715  332.2
# 52556  2018-12-31 23:20:00  0.0  0.0  18.26  48.02  87470.70  1.703  320.5
# 52557  2018-12-31 23:30:00  0.0  0.0  18.39  46.84  87455.03  2.887  335.7
# 52558  2018-12-31 23:40:00  0.0  0.0  17.99  47.85  87470.02  1.528  358.8
# 52559  2018-12-31 23:50:00  0.0  0.0  17.75  49.65  87467.29  0.598  322.3
#
#        alturasolar     azimuth
# 0       -79.806160  166.773196
# 1       -81.878940  170.053742
# 2       -83.764991  173.367191
# 3       -85.236372  176.703016
# 4       -85.827949 -179.949903
# ...            ...         ...
# 52555   -68.725457  151.345160
# 52556   -71.001501  154.338568
# 52557   -73.264218  157.400817
# 52558   -75.506650  160.527038
# 52559   -77.716959  163.711070
#
# [52560 rows x 10 columns]

# %% [markdown]
# # Identify the ubication of the datavoids (date, location and length)

# %%
isteps,datavoids,idates=imp.void_identifier(tmx_inc,'Ig')
# Out:
# new_void_at: 2018-01-30 07:20:00
# at index 4220
# 67
# new_void_at: 2018-03-29 06:40:00
# at index 12568
# 73
# new_void_at: 2018-06-15 06:10:00
# at index 23797
# 79
# new_void_at: 2018-06-27 06:10:00
# at index 25525
# 79
# new_void_at: 2018-07-28 06:20:00
# at index 29990
# 78
# new_void_at: 2018-08-12 06:30:00
# at index 32151
# 76
# new_void_at: 2018-10-05 06:40:00
# at index 39928
# 70
# new_void_at: 2018-11-14 06:50:00
# at index 45689

# %% [markdown]
# #### Data voids location

# %%
isteps
# Out:
# [4220, 12568, 23797, 25525, 29990, 32151, 39928, 45689]

# %% [markdown]
# #### Data voids length

# %%
datavoids
# Out:
# [67, 73, 79, 79, 78, 76, 70, 67]

# %%
tmx_inc
# Out:
#                       time   Ib   Ig     to     RH         P     WS     WD  \
# 0      2018-01-01 00:00:00  0.0  0.0  18.70  36.34  87864.11  1.422  316.0
# 1      2018-01-01 00:10:00  0.0  0.0  18.95  35.29  87876.37  1.008  283.7
# 2      2018-01-01 00:20:00  0.0  0.0  18.94  35.43  87888.64  1.565  326.0
# 3      2018-01-01 00:30:00  0.0  0.0  18.77  35.89  87887.21  2.175  354.5
# 4      2018-01-01 00:40:00  0.0  0.0  18.81  36.34  87886.91  1.902  348.0
# ...                    ...  ...  ...    ...    ...       ...    ...    ...
# 52555  2018-12-31 23:10:00  0.0  0.0  18.51  47.29  87484.32  1.715  332.2
# 52556  2018-12-31 23:20:00  0.0  0.0  18.26  48.02  87470.70  1.703  320.5
# 52557  2018-12-31 23:30:00  0.0  0.0  18.39  46.84  87455.03  2.887  335.7
# 52558  2018-12-31 23:40:00  0.0  0.0  17.99  47.85  87470.02  1.528  358.8
# 52559  2018-12-31 23:50:00  0.0  0.0  17.75  49.65  87467.29  0.598  322.3
#
#        alturasolar     azimuth
# 0       -79.806160  166.773196
# 1       -81.878940  170.053742
# 2       -83.764991  173.367191
# 3       -85.236372  176.703016
# 4       -85.827949 -179.949903
# ...            ...         ...
# 52555   -68.725457  151.345160
# 52556   -71.001501  154.338568
# 52557   -73.264218  157.400817
# 52558   -75.506650  160.527038
# 52559   -77.716959  163.711070
#
# [52560 rows x 10 columns]

# %% [markdown]
# ### Verifico que s'i hay un vac'io de datos

# %%
for istep in range(len(isteps)):
    fig, ax=plt.subplots(figsize=(20,10))
    ax.plot(tmx_inc['Ig'].loc[isteps[istep]-144:isteps[istep]+288])

# %% [markdown]
# # Imputo datos, con la lista de la ubicaci'on  de los vac'ios de datos

# %% [markdown]
# ## Este es con el exporta mas sencillo

# %%
nombres1=['time','Ib','Ig','to','RH','P','WS','WD','alturasolar','azimuth']
esoru=imp.importa('../../01_weather_data/03_imputing_process/01_test_data/tmx_incomplete_solar_angles.csv',nombres1)
in_size,out_size= 6,6 
model_name='../../03_CNN-LSTM_training/02_grid_training/01_models/train_seasonal_layers_2_2_1_out_s_6in_s_6_lr_0.0001_Global_BS12.h5'
scalery=load(open('../../03_CNN-LSTM_training/02_grid_training/03_scalers/y_scalerv06.pkl','rb'))
scalerx=load(open('../../03_CNN-LSTM_training/02_grid_training/03_scalers/x_scalerv06.pkl','rb'))
inputs=['Ig','Ib','to','RH','azimuth','alturasolar']
outputs=['Ig']
training_step=1
season_size=144
path_archivo2='../../01_weather_data/03_imputing_process/02_imputed_data/'
nombre_archivo2='tmx_CNN-LSTM_imputed.csv' #t minuscula es el nuevo

model=load_model(model_name)
tmx_inc.to_csv(path_archivo2+nombre_archivo2) #Saving the incomplete data in the file that 
#will become the imputed data

for void in range(len(datavoids)):
    predi,targ=imp.Multioneshot(esoru,datavoids[void],out_size,in_size,isteps[void]-144,
                                model,inputs,outputs,training_step,season_size,scalerx,scalery)
    imputed=imp.exporta(path_archivo2+nombre_archivo2,'Ig',predi,isteps[void],datavoids[void],
                                 nombres1,path_exported_file=path_archivo2+nombre_archivo2,save=True)
# Out:
# 2021-10-19 19:35:16.476163: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-10-19 19:35:17.665102: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/aigz/.pyenv/versions/3.9.5/lib/python3.9/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
imputed_csv=pd.read_csv('../../01_weather_data/03_imputing_process/02_imputed_data/tmx_CNN-LSTM_imputed.csv',index_col=0,parse_dates=True)
imputed_csv
# Out:
#                      Unnamed: 0   Ib   Ig     to     RH         P     WS  \
# time
# 2018-01-01 00:00:00           0  0.0  0.0  18.70  36.34  87864.11  1.422
# 2018-01-01 00:10:00           1  0.0  0.0  18.95  35.29  87876.37  1.008
# 2018-01-01 00:20:00           2  0.0  0.0  18.94  35.43  87888.64  1.565
# 2018-01-01 00:30:00           3  0.0  0.0  18.77  35.89  87887.21  2.175
# 2018-01-01 00:40:00           4  0.0  0.0  18.81  36.34  87886.91  1.902
# ...                         ...  ...  ...    ...    ...       ...    ...
# 2018-12-31 23:10:00       52555  0.0  0.0  18.51  47.29  87484.32  1.715
# 2018-12-31 23:20:00       52556  0.0  0.0  18.26  48.02  87470.70  1.703
# 2018-12-31 23:30:00       52557  0.0  0.0  18.39  46.84  87455.03  2.887
# 2018-12-31 23:40:00       52558  0.0  0.0  17.99  47.85  87470.02  1.528
# 2018-12-31 23:50:00       52559  0.0  0.0  17.75  49.65  87467.29  0.598
#
#                         WD  alturasolar     azimuth
# time
# 2018-01-01 00:00:00  316.0   -79.806160  166.773196
# 2018-01-01 00:10:00  283.7   -81.878940  170.053742
# 2018-01-01 00:20:00  326.0   -83.764991  173.367191
# 2018-01-01 00:30:00  354.5   -85.236372  176.703016
# 2018-01-01 00:40:00  348.0   -85.827949 -179.949903
# ...                    ...          ...         ...
# 2018-12-31 23:10:00  332.2   -68.725457  151.345160
# 2018-12-31 23:20:00  320.5   -71.001501  154.338568
# 2018-12-31 23:30:00  335.7   -73.264218  157.400817
# 2018-12-31 23:40:00  358.8   -75.506650  160.527038
# 2018-12-31 23:50:00  322.3   -77.716959  163.711070
#
# [52560 rows x 10 columns]

# %% [markdown]
# ### Importo tambien csv con datos completos

# %%
comp=pd.read_csv('../../01_weather_data/03_imputing_process/01_test_data/base_temixco.csv',index_col=0,parse_dates=True)

# %%
dias=['2018-03-29',
'2018-01-30',
'2018-06-27',
'2018-06-15',
'2018-07-28',
'2018-08-12',
'2018-10-05',
'2018-11-14']

# %%
idates
# Out:
# ['2018-01-30 07:20:00',
#  '2018-03-29 06:40:00',
#  '2018-06-15 06:10:00',
#  '2018-06-27 06:10:00',
#  '2018-07-28 06:20:00',
#  '2018-08-12 06:30:00',
#  '2018-10-05 06:40:00',
#  '2018-11-14 06:50:00']

# %%
calplot.calplot(imputed_csv.Ig,cmap='jet')
calplot.calplot(comp.Ig,cmap='jet')
# Out:
# (<Figure size 900x122.4 with 2 Axes>,
#  array([<AxesSubplot:ylabel='2018'>], dtype=object))

# %% [markdown]
# ## Grafico los datos imputados contra los reales, de los dias que hac'ian falta

# %%
comp['me']=np.abs(comp.Ig-imputed_csv.Ig)
meyear=comp.me.resample('D').mean()
for dia in dias:
    fig, ax=plt.subplots(figsize=(20,5))
    print('day_mae:',meyear[dia])
    plt.plot(imputed_csv.Ig[dia],'g.-',label='imputado')
    plt.plot(comp.Ig[dia],'k-',label='real')
    plt.plot(comp.me[dia],'r.',label='error')
    plt.legend(fontsize=20)
    plt.show()
# Out:
# day_mae: 16.349050232304467
# day_mae: 70.66917798535029
# day_mae: 65.06391562891007
# day_mae: 152.8260415445434
# day_mae: 30.575609461837345
# day_mae: 144.8527112305959
# day_mae: 20.68598877223333
# day_mae: 167.03413568014568

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, None, 64)          448
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, None, 64)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, None, 64)          4160
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, None, 64)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, None, 128)         98816
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                49408
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 6)                 390
# =================================================================
# Total params: 153,222
# Trainable params: 153,222
# Non-trainable params: 0
# _________________________________________________________________
