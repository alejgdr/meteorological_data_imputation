# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from dateutil.parser import parse

# %%
archivo = '../../01_weather_data/03_imputing_process/02_imputed_data/Tmx_CNN-LSTM_imputed.csv'#'../01_data/01_PreEPW/imputed_SARIMA_0_1_1.csv"
epw = pd.read_csv(archivo,
                 index_col=0,
                 parse_dates=True)
epw.fillna(0,inplace=True)

# %%
epw
# Out:
#                      Unnamed: 0   Ib   Ig     to     RH         P     WS  \
# time
# 2018-01-01 00:00:00           0  0.0  0.0  18.70  36.34  87864.11  1.422
# 2018-01-01 00:10:00           1  0.0  0.0  18.95  35.29  87876.37  1.008
# 2018-01-01 00:20:00           2  0.0  0.0  18.94  35.43  87888.64  1.565
# 2018-01-01 00:30:00           3  0.0  0.0  18.77  35.89  87887.21  2.175
# 2018-01-01 00:40:00           4  0.0  0.0  18.81  36.34  87886.91  1.902
# ...                         ...  ...  ...    ...    ...       ...    ...
# 2018-12-31 23:10:00       52555  0.0  0.0  18.51  47.29  87484.32  1.715
# 2018-12-31 23:20:00       52556  0.0  0.0  18.26  48.02  87470.70  1.703
# 2018-12-31 23:30:00       52557  0.0  0.0  18.39  46.84  87455.03  2.887
# 2018-12-31 23:40:00       52558  0.0  0.0  17.99  47.85  87470.02  1.528
# 2018-12-31 23:50:00       52559  0.0  0.0  17.75  49.65  87467.29  0.598
#
#                         WD  alturasolar     azimuth
# time
# 2018-01-01 00:00:00  316.0   -79.806160  166.773196
# 2018-01-01 00:10:00  283.7   -81.878940  170.053742
# 2018-01-01 00:20:00  326.0   -83.764991  173.367191
# 2018-01-01 00:30:00  354.5   -85.236372  176.703016
# 2018-01-01 00:40:00  348.0   -85.827949 -179.949903
# ...                    ...          ...         ...
# 2018-12-31 23:10:00  332.2   -68.725457  151.345160
# 2018-12-31 23:20:00  320.5   -71.001501  154.338568
# 2018-12-31 23:30:00  335.7   -73.264218  157.400817
# 2018-12-31 23:40:00  358.8   -75.506650  160.527038
# 2018-12-31 23:50:00  322.3   -77.716959  163.711070
#
# [52560 rows x 10 columns]

# %%
epw.plot(subplots=True,figsize=(20,40));

# %%
def df2epw(df):
    df['anio']    = df.index.year
    df['mes']     = df.index.month
    df['dia']     = df.index.day
    df['hora']    = df.index.hour
    df['minutos'] = df.index.minute
    return df[1:]

# %%
columnas = ['anio','mes','dia','hora','minutos',
            'to','RH','P',"Ig","Ib",'WD','WS']
tmp = df2epw(epw)

tmp.to_csv( "../../01_weather_data/03_imputing_process/03_to_EPWs/tmx_2018_imputed_cnn_lstm_EPW.csv",
           columns=columnas,header=False,index=False)

# %%
tmp[columnas]
# Out:
#                      anio  mes  dia  hora  minutos     to     RH         P  \
# time
# 2018-01-01 00:10:00  2018    1    1     0       10  18.95  35.29  87876.37
# 2018-01-01 00:20:00  2018    1    1     0       20  18.94  35.43  87888.64
# 2018-01-01 00:30:00  2018    1    1     0       30  18.77  35.89  87887.21
# 2018-01-01 00:40:00  2018    1    1     0       40  18.81  36.34  87886.91
# 2018-01-01 00:50:00  2018    1    1     0       50  19.23  35.40  87889.36
# ...                   ...  ...  ...   ...      ...    ...    ...       ...
# 2018-12-31 23:10:00  2018   12   31    23       10  18.51  47.29  87484.32
# 2018-12-31 23:20:00  2018   12   31    23       20  18.26  48.02  87470.70
# 2018-12-31 23:30:00  2018   12   31    23       30  18.39  46.84  87455.03
# 2018-12-31 23:40:00  2018   12   31    23       40  17.99  47.85  87470.02
# 2018-12-31 23:50:00  2018   12   31    23       50  17.75  49.65  87467.29
#
#                       Ig   Ib       WD     WS
# time
# 2018-01-01 00:10:00  0.0  0.0  283.700  1.008
# 2018-01-01 00:20:00  0.0  0.0  326.000  1.565
# 2018-01-01 00:30:00  0.0  0.0  354.500  2.175
# 2018-01-01 00:40:00  0.0  0.0  348.000  1.902
# 2018-01-01 00:50:00  0.0  0.0    6.668  1.468
# ...                  ...  ...      ...    ...
# 2018-12-31 23:10:00  0.0  0.0  332.200  1.715
# 2018-12-31 23:20:00  0.0  0.0  320.500  1.703
# 2018-12-31 23:30:00  0.0  0.0  335.700  2.887
# 2018-12-31 23:40:00  0.0  0.0  358.800  1.528
# 2018-12-31 23:50:00  0.0  0.0  322.300  0.598
#
# [52559 rows x 12 columns]

# %%
import calplot
calplot.calplot(tmp.Ig)
# Out:
# (<Figure size 900x122.4 with 2 Axes>,
#  array([<AxesSubplot:ylabel='2018'>], dtype=object))

# %%
plt.plot(tmp.Ig.loc['2018-06-01'],'r.')

# %%
# auxiliary programs > weather converter
