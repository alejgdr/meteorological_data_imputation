# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from dateutil.parser import parse

# %%
imputed_file = '../../01_weather_data/03_imputing_process/02_imputed_data/tmx_46days_imputed'#01_test_data/tmx_base_2018_solar_angles.csv'#02_imputed_data/Tmx_CNN-LSTM_imputed.csv'#'../01_data/01_PreEPW/imputed_SARIMA_0_1_1.csv"
to_epw_file= '../../01_weather_data/04_to_EPWs/imputed_46days.csv' #base_epw_adiabatic.csv
epw = pd.read_csv(imputed_file,
                 index_col=0,
                 parse_dates=True)
epw.fillna(0,inplace=True)

# %%
epw
# Out:
#                       Ib   Ig     to     RH         P     WS     WD  \
# time
# 2018-01-01 00:00:00  0.0  0.0  18.70  36.34  87864.11  1.422  316.0
# 2018-01-01 00:10:00  0.0  0.0  18.95  35.29  87876.37  1.008  283.7
# 2018-01-01 00:20:00  0.0  0.0  18.94  35.43  87888.64  1.565  326.0
# 2018-01-01 00:30:00  0.0  0.0  18.77  35.89  87887.21  2.175  354.5
# 2018-01-01 00:40:00  0.0  0.0  18.81  36.34  87886.91  1.902  348.0
# ...                  ...  ...    ...    ...       ...    ...    ...
# 2018-12-31 23:10:00  0.0  0.0  18.51  47.29  87484.32  1.715  332.2
# 2018-12-31 23:20:00  0.0  0.0  18.26  48.02  87470.70  1.703  320.5
# 2018-12-31 23:30:00  0.0  0.0  18.39  46.84  87455.03  2.887  335.7
# 2018-12-31 23:40:00  0.0  0.0  17.99  47.85  87470.02  1.528  358.8
# 2018-12-31 23:50:00  0.0  0.0  17.75  49.65  87467.29  0.598  322.3
#
#                      alturasolar     azimuth
# time
# 2018-01-01 00:00:00   -79.806160  166.773196
# 2018-01-01 00:10:00   -81.878940  170.053742
# 2018-01-01 00:20:00   -83.764991  173.367191
# 2018-01-01 00:30:00   -85.236372  176.703016
# 2018-01-01 00:40:00   -85.827949 -179.949903
# ...                          ...         ...
# 2018-12-31 23:10:00   -68.725457  151.345160
# 2018-12-31 23:20:00   -71.001501  154.338568
# 2018-12-31 23:30:00   -73.264218  157.400817
# 2018-12-31 23:40:00   -75.506650  160.527038
# 2018-12-31 23:50:00   -77.716959  163.711070
#
# [52560 rows x 9 columns]

# %%
epw.plot(subplots=True,figsize=(20,40));

# %%
def df2epw(df):
    df['anio']    = df.index.year
    df['mes']     = df.index.month
    df['dia']     = df.index.day
    df['hora']    = df.index.hour
    df['minutos'] = df.index.minute
    return df[1:]

# %%
columnas = ['anio','mes','dia','hora','minutos',
            'to','RH','P',"Ig","Ib",'WD','WS']
tmp = df2epw(epw)

tmp.to_csv(to_epw_file,
           columns=columnas,header=False,index=False)

# %%
tmp
# Out:
#                       Ib   Ig     to     RH         P     WS       WD  \
# time
# 2018-01-01 00:10:00  0.0  0.0  18.95  35.29  87876.37  1.008  283.700
# 2018-01-01 00:20:00  0.0  0.0  18.94  35.43  87888.64  1.565  326.000
# 2018-01-01 00:30:00  0.0  0.0  18.77  35.89  87887.21  2.175  354.500
# 2018-01-01 00:40:00  0.0  0.0  18.81  36.34  87886.91  1.902  348.000
# 2018-01-01 00:50:00  0.0  0.0  19.23  35.40  87889.36  1.468    6.668
# ...                  ...  ...    ...    ...       ...    ...      ...
# 2018-12-31 23:10:00  0.0  0.0  18.51  47.29  87484.32  1.715  332.200
# 2018-12-31 23:20:00  0.0  0.0  18.26  48.02  87470.70  1.703  320.500
# 2018-12-31 23:30:00  0.0  0.0  18.39  46.84  87455.03  2.887  335.700
# 2018-12-31 23:40:00  0.0  0.0  17.99  47.85  87470.02  1.528  358.800
# 2018-12-31 23:50:00  0.0  0.0  17.75  49.65  87467.29  0.598  322.300
#
#                      alturasolar     azimuth  anio  mes  dia  hora  minutos
# time
# 2018-01-01 00:10:00   -81.878940  170.053742  2018    1    1     0       10
# 2018-01-01 00:20:00   -83.764991  173.367191  2018    1    1     0       20
# 2018-01-01 00:30:00   -85.236372  176.703016  2018    1    1     0       30
# 2018-01-01 00:40:00   -85.827949 -179.949903  2018    1    1     0       40
# 2018-01-01 00:50:00   -85.202271 -176.602993  2018    1    1     0       50
# ...                          ...         ...   ...  ...  ...   ...      ...
# 2018-12-31 23:10:00   -68.725457  151.345160  2018   12   31    23       10
# 2018-12-31 23:20:00   -71.001501  154.338568  2018   12   31    23       20
# 2018-12-31 23:30:00   -73.264218  157.400817  2018   12   31    23       30
# 2018-12-31 23:40:00   -75.506650  160.527038  2018   12   31    23       40
# 2018-12-31 23:50:00   -77.716959  163.711070  2018   12   31    23       50
#
# [52559 rows x 14 columns]

# %%
len(tmp.Ig)
# Out:
# 52559

# %%
import calplot
calplot.calplot(tmp.Ig)
# Out:
# (<Figure size 900x122.4 with 2 Axes>,
#  array([<AxesSubplot:ylabel='2018'>], dtype=object))

# %%
plt.plot(tmp.Ig.loc['2018-06-01'],'r.')

# %%
# auxiliary programs > weather converter
